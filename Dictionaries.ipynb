# %% [markdown]
# <a href="https://colab.research.google.com/github/Rickary20/Rickary20/blob/master/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car_specifics={
    "Make": "Toyota",
    "YOM": 2019,
    "Color": "White",
    "Mileage": 37000,

}
car_specifics
# Out:
# {'Make': 'Toyota', 'YOM': 2019, 'Color': 'White', 'Mileage': 37000}

# %%
car_specifics["Make"]
# Out:
# 'Toyota'

# %%
car_specifics
# Out:
# {'Make': 'Toyota', 'YOM': 2019, 'Color': 'White', 'Mileage': 37000}

# %%
car_specifics.keys()
# Out:
# dict_keys(['Make', 'YOM', 'Color', 'Mileage'])

# %%
car_specifics.values()
# Out:
# dict_values(['Toyota', 2019, 'White', 37000])

# %%
for i in car_specifics:
  print(i)
# Out:
# Make
# YOM
# Color
# Mileage

# %%
for item in car_specifics.values():
  print(item)
# Out:
# Toyota
# 2019
# White
# 37000

# %%
car_specifics.pop("Mileage")
# Out:
# 37000

# %%
car_specifics.values()
# Out:
# dict_values(['Toyota', 2019, 'White'])

# %%
car_specifics["Country"]="Japan"

# %%
car_specifics
# Out:
# {'Make': 'Toyota', 'YOM': 2019, 'Color': 'White', 'Country': 'Japan'}

# %%
car_specifics.get("Color")
# Out:
# 'White'

# %%
car_specifics.update({"YOM":2021})

# %%
car_specifics
# Out:
# {'Make': 'Toyota', 'YOM': 2021, 'Color': 'White', 'Country': 'Japan'}

# %%
car_specifics_copy=car_specifics.copy()
car_specifics_copy
car_specifics.update({"Color": "Red_Wine"})
car_specifics_copy
# Out:
# {'Make': 'Toyota', 'YOM': 2021, 'Color': 'Red_Wine', 'Country': 'Japan'}
